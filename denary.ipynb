# %%
import numpy as np

# 1) Source
X = [0, 1]
pX = [0.5, 0.5]

# 2) Distortion target
epsilon = 0.5
D = 0.3 /(1+epsilon)

# 3) Test channel p(hatX|X)
pX_hat_given_X = [
    [1 - D, D],   # X=0 → hatX=0/1
    [D, 1 - D]    # X=1 → hatX=0/1
]

# 4) Marginal p(hatX)
X_hat = [0, 1]
pX_hat = [0.5, 0.5]

# 5) Joint distribution p(X, hatX)
pXY = [
    [0.5 * (1 - D), 0.5 * D],
    [0.5 * D,       0.5 * (1 - D)]
]

print("D =", D)
print("pX =", pX)
print("pX_hat =", pX_hat)
print("pX_hat_given_X =\n", np.array(pX_hat_given_X))
print("pXY =\n", np.array(pXY))
# Out:
# D = 0.19999999999999998
# pX = [0.5, 0.5]
# pX_hat = [0.5, 0.5]
# pX_hat_given_X =
#  [[0.8 0.2]
#  [0.2 0.8]]
# pXY =
#  [[0.4 0.1]
#  [0.1 0.4]]

# %%
def Hamming_distortion(X, Xhat):
    assert X.shape == Xhat.shape, "X와 Xhat shape이 다름"
    mism = (X != Xhat)
    cnt = np.count_nonzero(mism)
    return cnt

# %%
import numpy as np

def random_bit(size=None):
    return np.random.randint(0, 2, size=size)

print(random_bit())          # 단일 0 또는 1
print(random_bit(10))        # [0 1 0 1 1 0 0 1 0 1]
# Out:
# 1
# [1 0 0 1 1 0 1 0 0 1]

# %%
import math
def mutual_information(X,Xhat):
    hap = 0
    for x in X:
        for x_hat in X_hat:
            hap += (pX[x] * pX_hat_given_X[x_hat][x] * 
                    math.log2(pX[x] * pX_hat_given_X[x_hat][x]/(pX[x]*
                                                                pX_hat[x_hat]))
                   )
    return hap        
def D_entropy(D):
    return -D*math.log2(D) -(1-D)*math.log2(1-D)

# %%
print("mutual_information = ",mutual_information(X, X_hat))
print("H(p) - H(D) = ", 1-D_entropy(D))
# Out:
# mutual_information =  0.2780719051126378
# H(p) - H(D) =  0.2780719051126377

# %%
import numpy as np

# ----- 3. 샘플 수 -----
N = 1000000

# ----- 4. X 샘플링 -----
X_samples = np.random.choice(X, size=N, p=pX)

# ----- 5. 조건부 분포에 따라 X_hat 샘플링 -----
Xhat_samples = np.empty(N, dtype=int)
for i, x in enumerate(X_samples):
    Xhat_samples[i] = np.random.choice(X_hat, p=pX_hat_given_X[x])

# ----- 6. Joint 분포 추정 -----
joint_counts = np.zeros((2, 2))
for x, xhat in zip(X_samples, Xhat_samples):
    joint_counts[x, xhat] += 1

joint_probs = joint_counts / N

# ----- 7. 평균 왜곡 측정 -----
distortion = np.mean(X_samples != Xhat_samples)

print("D =", D)
print("조건부 분포 p(X̂|X):")
print(pX_hat_given_X)
print("\nJoint empirical p(x, x̂):")
print(joint_probs)
print(f"\n평균 왜곡 ≈ {distortion:.4f}")
# Out:
# D = 0.19999999999999998
# 조건부 분포 p(X̂|X):
# [[0.8, 0.19999999999999998], [0.19999999999999998, 0.8]]
#
# Joint empirical p(x, x̂):
# [[0.39947  0.099247]
#  [0.100529 0.400754]]
#
# 평균 왜곡 ≈ 0.1998

# %%
Xhat_samples
# Out:
# array([0, 0, 0, ..., 0, 1, 1])

# %%
def codebook_generation(n, R, distribution):
    M = int(2 ** (n*R))
    codebook = np.random.choice([0, 1], size=(M, n), p=distribution)
    return codebook

# %%
n=80
R=mutual_information(X, X_hat) + 0.01
codebook = codebook_generation(n, R, pX_hat)
codebook.shape
np.sum(codebook, axis = 1).shape
# Out:
# (8658900,)

# %%
count = 1
for i in range(count):
    xn = random_bit(n)

# %%
def joint_empirical_pmf(x_seq: np.ndarray, y_seq: np.ndarray, X_alphabet, Y_alphabet):
    x_seq = np.asarray(x_seq)                     # 예: array([0,1,1,0])
    y_seq = np.asarray(y_seq)                     # 예: array([0,1,1,0])
    assert x_seq.shape == y_seq.shape and x_seq.ndim == 1

    # map symbols to indices
    x_to_idx = {sym:i for i, sym in enumerate(X_alphabet)}   # {0:0, 1:1}
    y_to_idx = {sym:j for j, sym in enumerate(Y_alphabet)}   # {0:0, 1:1}
    kx, ky = len(X_alphabet), len(Y_alphabet)                # kx=2, ky=2

    # encode to indices
    xi = np.vectorize(x_to_idx.__getitem__)(x_seq)           # [0,1,1,0]
    yj = np.vectorize(y_to_idx.__getitem__)(y_seq)           # [0,1,1,0]
    # joint counts
    idx = xi * ky + yj                                       
    # ky=2 이므로 xi*2 + yj → [0*2+0, 1*2+1, 1*2+1, 0*2+0] = [0,3,3,0]

    counts = np.bincount(idx, minlength=kx*ky).astype(float).reshape(kx, ky)
    # idx=[0,3,3,0] 이므로 bincount: [2,0,0,2] → reshape(2x2)=[[2,0],[0,2]]
    return counts / x_seq.size 
    # x_seq.size = 4 → [[2/4, 0/4],[0/4, 2/4]]
    # 결과: array([[0.5, 0.0], [0.0, 0.5]])

# %%
def is_jointly_typical(x_seq,
                       y_seq,
                       pXY,
                       X_alphabet,
                       Y_alphabet,
                       eps: float):
    """
    (x^n, y^n)이 주어졌을 때,
    정의:
      |π(x,y) - pXY(x,y)| <= eps * pXY(x,y)  (pXY(x,y) > 0인 모든 (x,y))
    이고,
      pXY(x,y) = 0 인 자리에서는 π(x,y)도 0 이어야 함
    을 만족하면 True (joint ε-typical), 아니면 False.
    """
    # 경험적 joint pmf π(x,y)
    pi = joint_empirical_pmf(x_seq, y_seq, X_alphabet, Y_alphabet)

    # 이론 joint pmf
    pXY = np.asarray(pXY, dtype=float)
    assert pi.shape == pXY.shape, "π와 pXY의 shape이 다릅니다."

    # (1) pXY(x,y) > 0 인 위치: 상대 오차 조건 검사
    pos = pXY > 0
    if np.any(np.abs(pi[pos] - pXY[pos]) > eps * pXY[pos]):
        return False

    # (2) pXY(x,y) = 0 인 위치: 실제로도 안 나와야 함
    zero = ~pos
    if np.any(pi[zero] > 0):
        return False

    return True

# %%
N=100000
#joint_empirical_pmf(np.random.choice(X_vals, size=N,p=px),np.random.choice(X_vals,  size=N,p=pX_hat),X,X_hat)

# %%
count = 100
zero_cnt = 0
block_distortions = []
for i in range(count):
    xn = random_bit(n)  # source block X^n
    found_index = None
    for idx, tempt in enumerate(codebook):   # tempt = codeword candidate
        if is_jointly_typical(xn, tempt, pXY, X, X_hat, eps=epsilon):
            found_index = idx
            break
    chosen = codebook[found_index]
    # print("source = " , xn)
    # print("codeword = ", chosen)
    dist = Hamming_distortion(xn, chosen)
    block_distortions.append(dist)
    if found_index is None:
        found_index = 0  # 못 찾았을 때 기본값 (논문에서 m=1)
        zero_cnt += 1
    print(f"Block {i}: chosen codeword index = {found_index}")
print("eps=",epsilon," Error source count =  ",zero_cnt)
print(f"- mean distortion over {count} blocks = {np.mean(block_distortions)/100:.4f}")
# Out:
# Block 0: chosen codeword index = 33558
# Block 1: chosen codeword index = 237540
# Block 2: chosen codeword index = 15229
# Block 3: chosen codeword index = 215629
# Block 4: chosen codeword index = 136284
# Block 5: chosen codeword index = 54050
# Block 6: chosen codeword index = 338830
# Block 7: chosen codeword index = 143609
# Block 8: chosen codeword index = 141812
# Block 9: chosen codeword index = 119918
# Block 10: chosen codeword index = 26234
# Block 11: chosen codeword index = 175984
# Block 12: chosen codeword index = 7677
# Block 13: chosen codeword index = 56698
# Block 14: chosen codeword index = 50245
# Block 15: chosen codeword index = 33461
# Block 16: chosen codeword index = 241071
# Block 17: chosen codeword index = 7449
# Block 18: chosen codeword index = 89074
# Block 19: chosen codeword index = 107717
# Block 20: chosen codeword index = 158202
# Block 21: chosen codeword index = 221022
# Block 22: chosen codeword index = 214475
# Block 23: chosen codeword index = 22338
# Block 24: chosen codeword index = 178392
# Block 25: chosen codeword index = 16655
# Block 26: chosen codeword index = 19344
# Block 27: chosen codeword index = 313437
# Block 28: chosen codeword index = 556519
# Block 29: chosen codeword index = 130675
# Block 30: chosen codeword index = 7633
# Block 31: chosen codeword index = 226276
# Block 32: chosen codeword index = 54501
# Block 33: chosen codeword index = 165211
# Block 34: chosen codeword index = 121576
# Block 35: chosen codeword index = 51882
# Block 36: chosen codeword index = 63516
# Block 37: chosen codeword index = 172457
# Block 38: chosen codeword index = 3367
# Block 39: chosen codeword index = 20261
# Block 40: chosen codeword index = 150033
# Block 41: chosen codeword index = 3676
# Block 42: chosen codeword index = 121143
# Block 43: chosen codeword index = 102446
# Block 44: chosen codeword index = 53429
# Block 45: chosen codeword index = 56996
# Block 46: chosen codeword index = 19746
# Block 47: chosen codeword index = 87195
# Block 48: chosen codeword index = 176713
# Block 49: chosen codeword index = 10942
# Block 50: chosen codeword index = 59807
# Block 51: chosen codeword index = 79759
# Block 52: chosen codeword index = 281309
# Block 53: chosen codeword index = 11146
# Block 54: chosen codeword index = 4088
# Block 55: chosen codeword index = 45040
# Block 56: chosen codeword index = 145329
# Block 57: chosen codeword index = 114664
# Block 58: chosen codeword index = 10287
# Block 59: chosen codeword index = 177170
# Block 60: chosen codeword index = 342534
# Block 61: chosen codeword index = 65303
# Block 62: chosen codeword index = 401437
# Block 63: chosen codeword index = 224997
# Block 64: chosen codeword index = 102852
# Block 65: chosen codeword index = 40245
# Block 66: chosen codeword index = 77986
# Block 67: chosen codeword index = 137364
# Block 68: chosen codeword index = 56105
# Block 69: chosen codeword index = 188310
# Block 70: chosen codeword index = 93780
# Block 71: chosen codeword index = 64536
# Block 72: chosen codeword index = 81728
# Block 73: chosen codeword index = 9253
# Block 74: chosen codeword index = 183958
# Block 75: chosen codeword index = 77176
# Block 76: chosen codeword index = 198166
# Block 77: chosen codeword index = 70121
# Block 78: chosen codeword index = 9563
# Block 79: chosen codeword index = 93959
# Block 80: chosen codeword index = 66024
# Block 81: chosen codeword index = 34369
# Block 82: chosen codeword index = 203362
# Block 83: chosen codeword index = 18047
# Block 84: chosen codeword index = 31164
# Block 85: chosen codeword index = 89548
# Block 86: chosen codeword index = 305562
# Block 87: chosen codeword index = 484554
# Block 88: chosen codeword index = 47973
# Block 89: chosen codeword index = 155490
# Block 90: chosen codeword index = 293940
# Block 91: chosen codeword index = 1196
# Block 92: chosen codeword index = 25400
# Block 93: chosen codeword index = 66143
# Block 94: chosen codeword index = 7637
# Block 95: chosen codeword index = 8558
# Block 96: chosen codeword index = 193328
# Block 97: chosen codeword index = 26500
# Block 98: chosen codeword index = 78773
# Block 99: chosen codeword index = 28638
# eps= 0.5  Error source count =   0
# - mean distortion over 100 blocks = 0.2098

# %%
print("eps=",epsilon," Error source count =  ",zero_cnt)

# %%
import numpy as np

# 1) Source
X = [0, 1]
pX = [0.5, 0.5]

# 2) Distortion target
epsilon = 0.1
D = 0.1 + epsilon

# 3) Test channel p(hatX|X)
pX_hat_given_X = [
    [1 - D, D],   # X=0 → hatX=0/1
    [D, 1 - D]    # X=1 → hatX=0/1
]

# 4) Marginal p(hatX)
X_hat = [0, 1]
pX_hat = [0.5, 0.5]

# 5) Joint distribution p(X, hatX)
pXY = [
    [0.5 * (1 - D), 0.5 * D],
    [0.5 * D,       0.5 * (1 - D)]
]

print("D =", D)
print("pX =", pX)
print("pX_hat =", pX_hat)
print("pX_hat_given_X =\n", np.array(pX_hat_given_X))
print("pXY =\n", np.array(pXY))
