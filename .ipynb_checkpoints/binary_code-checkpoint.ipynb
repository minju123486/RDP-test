# %%
import numpy as np
X = [0,1] # source
px = [1/2, 1/2] # source
X_hat = [0,1]
pX_hat = [1/2, 1/2]
X_HatcoditionedX = [[0,1],[0,1]]
pX_HatcoditionedX = [[0.67, 0.33], [0.33, 0.67]]
pXY = [[0.335, 0.165],[0.165, 0.335]]

# %%
def Hamming_distortion(X, Xhat):
    assert X.shape == Xhat.shape, "X와 Xhat shape이 다름"
    mism = (X != Xhat)
    cnt = np.count_nonzero(mism)
    return cnt

# %%
import numpy as np

def random_bit(size=None):
    return np.random.randint(0, 2, size=size)

print(random_bit())          # 단일 0 또는 1
print(random_bit(10))        # [0 1 0 1 1 0 0 1 0 1]
# Out:
# 1
# [0 1 0 0 0 1 1 1 1 1]

# %%
import math
def mutual_information(X,Xhat):
    hap = 0
    for x in X:
        for x_hat in X_hat:
            hap += (px[x] * pX_HatcoditionedX[x_hat][x] * 
                    math.log2(px[x] * pX_HatcoditionedX[x_hat][x]/(px[x]*
                                                                pX_hat[x_hat]))
                   )
    return hap

# %%
mutual_information(X, X_hat)
# Out:
# 0.08507362722027256

# %%
import numpy as np

#조건부 분포 검증

# 정의
X_vals = np.array([0, 1])
pX = np.array([0.5, 0.5])
pX_hat = np.array([0.5, 0.5])
pXhat_given_X = np.array([[0.67, 0.33],
                          [0.33, 0.67]]) 

# 샘플 수
N = 100_000

# 1. X 샘플링 (Bern(1/2))
X_samples = np.random.choice(X_vals, size=N, p=pX)

# 2. X_hat 샘플링 (조건부 분포 이용)
Xhat_samples = np.empty(N, dtype=int)
for i, x in enumerate(X_samples):
    Xhat_samples[i] = np.random.choice(X_vals, p=pXhat_given_X[x])

# 3. joint 빈도 및 왜곡 확인
joint_counts = np.zeros((2, 2))
for x, xhat in zip(X_samples, Xhat_samples):
    joint_counts[x, xhat] += 1
joint_probs = joint_counts / N

# 4. 평균 왜곡 (해밍)
distortion = np.mean(X_samples != Xhat_samples)

print("Joint empirical p(x, x̂):")
print(joint_probs)
print(f"평균 왜곡 ≈ {distortion:.3f}")
# Out:
# Joint empirical p(x, x̂):
# [[0.33472 0.16285]
#  [0.165   0.33743]]
# 평균 왜곡 ≈ 0.328

# %%
Xhat_samples
# Out:
# array([1, 0, 0, ..., 1, 0, 0])

# %%
def codebook_generation(n, R, distribution):
    M = int(2 ** (n*R))
    codebook = np.random.choice([0, 1], size=(M, n), p=distribution)
    return codebook

# %%
n=160
R=0.12
codebook = codebook_generation(n, R, pX_hat)
codebook.shape
np.sum(codebook, axis = 1).shape
# Out:
# (602248,)

# %%
count = 1
for i in range(count):
    xn = random_bit(n)

# %%
def joint_empirical_pmf(x_seq: np.ndarray, y_seq: np.ndarray, X_alphabet, Y_alphabet):
    x_seq = np.asarray(x_seq)                     # 예: array([0,1,1,0])
    y_seq = np.asarray(y_seq)                     # 예: array([0,1,1,0])
    assert x_seq.shape == y_seq.shape and x_seq.ndim == 1

    # map symbols to indices
    x_to_idx = {sym:i for i, sym in enumerate(X_alphabet)}   # {0:0, 1:1}
    y_to_idx = {sym:j for j, sym in enumerate(Y_alphabet)}   # {0:0, 1:1}
    kx, ky = len(X_alphabet), len(Y_alphabet)                # kx=2, ky=2

    # encode to indices
    xi = np.vectorize(x_to_idx.__getitem__)(x_seq)           # [0,1,1,0]
    yj = np.vectorize(y_to_idx.__getitem__)(y_seq)           # [0,1,1,0]
    # joint counts
    idx = xi * ky + yj                                       
    # ky=2 이므로 xi*2 + yj → [0*2+0, 1*2+1, 1*2+1, 0*2+0] = [0,3,3,0]

    counts = np.bincount(idx, minlength=kx*ky).astype(float).reshape(kx, ky)
    # idx=[0,3,3,0] 이므로 bincount: [2,0,0,2] → reshape(2x2)=[[2,0],[0,2]]
    return counts / x_seq.size 
    # x_seq.size = 4 → [[2/4, 0/4],[0/4, 2/4]]
    # 결과: array([[0.5, 0.0], [0.0, 0.5]])

# %%
def is_jointly_typical(x_seq,
                       y_seq,
                       pXY,
                       X_alphabet,
                       Y_alphabet,
                       eps: float):
    """
    (x^n, y^n)이 주어졌을 때,
    정의:
      |π(x,y) - pXY(x,y)| <= eps * pXY(x,y)  (pXY(x,y) > 0인 모든 (x,y))
    이고,
      pXY(x,y) = 0 인 자리에서는 π(x,y)도 0 이어야 함
    을 만족하면 True (joint ε-typical), 아니면 False.
    """
    # 경험적 joint pmf π(x,y)
    pi = joint_empirical_pmf(x_seq, y_seq, X_alphabet, Y_alphabet)

    # 이론 joint pmf
    pXY = np.asarray(pXY, dtype=float)
    assert pi.shape == pXY.shape, "π와 pXY의 shape이 다릅니다."

    # (1) pXY(x,y) > 0 인 위치: 상대 오차 조건 검사
    pos = pXY > 0
    if np.any(np.abs(pi[pos] - pXY[pos]) > eps * pXY[pos]):
        return False

    # (2) pXY(x,y) = 0 인 위치: 실제로도 안 나와야 함
    zero = ~pos
    if np.any(pi[zero] > 0):
        return False

    return True

# %%
N=100000
joint_empirical_pmf(np.random.choice(X_vals, size=N,p=px),np.random.choice(X_vals,  size=N,p=pX_hat),X,X_hat)
# Out:
# array([[0.24969, 0.25076],
#        [0.25136, 0.24819]])

# %%
count = 1000
zero_cnt = 0
epsilon = 0.25
for i in range(count):
    xn = random_bit(n)  # source block X^n
    found_index = None
    for idx, tempt in enumerate(codebook):   # tempt = codeword candidate
        if is_jointly_typical(xn, tempt, pXY, X, X_hat, eps=epsilon):
            found_index = idx
            break

    if found_index is None:
        found_index = 0  # 못 찾았을 때 기본값 (논문에서 m=1)
        zero_cnt += 1
    print(f"Block {i}: chosen codeword index = {found_index}")
print("eps=",epsilon," Error source count =  ",zero_cnt)
# Out:
# Block 0: chosen codeword index = 2844
# Block 1: chosen codeword index = 2730
# Block 2: chosen codeword index = 721
# Block 3: chosen codeword index = 642
# Block 4: chosen codeword index = 1310
# Block 5: chosen codeword index = 2865
# Block 6: chosen codeword index = 501
# Block 7: chosen codeword index = 961
# Block 8: chosen codeword index = 27
# Block 9: chosen codeword index = 106
# Block 10: chosen codeword index = 4315
# Block 11: chosen codeword index = 2081
# Block 12: chosen codeword index = 60
# Block 13: chosen codeword index = 766
# Block 14: chosen codeword index = 18585
# Block 15: chosen codeword index = 63
# Block 16: chosen codeword index = 1
# Block 17: chosen codeword index = 1288
# Block 18: chosen codeword index = 291
# Block 19: chosen codeword index = 2013
# Block 20: chosen codeword index = 383
# Block 21: chosen codeword index = 1899
# Block 22: chosen codeword index = 1093
# Block 23: chosen codeword index = 3277
# Block 24: chosen codeword index = 1574
# Block 25: chosen codeword index = 210
# Block 26: chosen codeword index = 1119
# Block 27: chosen codeword index = 4732
# Block 28: chosen codeword index = 378
# Block 29: chosen codeword index = 1312
# Block 30: chosen codeword index = 193
# Block 31: chosen codeword index = 2095
# Block 32: chosen codeword index = 5609
# Block 33: chosen codeword index = 230
# Block 34: chosen codeword index = 1039
# Block 35: chosen codeword index = 159
# Block 36: chosen codeword index = 4015
# Block 37: chosen codeword index = 2800
# Block 38: chosen codeword index = 74
# Block 39: chosen codeword index = 2001
# Block 40: chosen codeword index = 1193
# Block 41: chosen codeword index = 295
# Block 42: chosen codeword index = 650
# Block 43: chosen codeword index = 6267
# Block 44: chosen codeword index = 2729
# Block 45: chosen codeword index = 1461
# Block 46: chosen codeword index = 2298
# Block 47: chosen codeword index = 326
# Block 48: chosen codeword index = 858
# Block 49: chosen codeword index = 2127
# Block 50: chosen codeword index = 2688
# Block 51: chosen codeword index = 995
# Block 52: chosen codeword index = 491
# Block 53: chosen codeword index = 77
# Block 54: chosen codeword index = 547
# Block 55: chosen codeword index = 64
# Block 56: chosen codeword index = 1376
# Block 57: chosen codeword index = 4167
# Block 58: chosen codeword index = 2705
# Block 59: chosen codeword index = 1290
# Block 60: chosen codeword index = 430
# Block 61: chosen codeword index = 2841
# Block 62: chosen codeword index = 317813
# Block 63: chosen codeword index = 444
# Block 64: chosen codeword index = 6063
# Block 65: chosen codeword index = 179
# Block 66: chosen codeword index = 734
# Block 67: chosen codeword index = 182
# Block 68: chosen codeword index = 291
# Block 69: chosen codeword index = 1303
# Block 70: chosen codeword index = 8
# Block 71: chosen codeword index = 4605
# Block 72: chosen codeword index = 4210
# Block 73: chosen codeword index = 2531
# Block 74: chosen codeword index = 4198
# Block 75: chosen codeword index = 2345
# Block 76: chosen codeword index = 6548
# Block 77: chosen codeword index = 15464
# Block 78: chosen codeword index = 1027
# Block 79: chosen codeword index = 463
# Block 80: chosen codeword index = 5287
# Block 81: chosen codeword index = 23076
# Block 82: chosen codeword index = 1641
# Block 83: chosen codeword index = 6207
# Block 84: chosen codeword index = 512
# Block 85: chosen codeword index = 2037
# Block 86: chosen codeword index = 87
# Block 87: chosen codeword index = 563
# Block 88: chosen codeword index = 3791
# Block 89: chosen codeword index = 646
# Block 90: chosen codeword index = 1274
# Block 91: chosen codeword index = 3920
# Block 92: chosen codeword index = 2918
# Block 93: chosen codeword index = 42
# Block 94: chosen codeword index = 2489
# Block 95: chosen codeword index = 558
# Block 96: chosen codeword index = 1573
# Block 97: chosen codeword index = 1138
# Block 98: chosen codeword index = 139
# Block 99: chosen codeword index = 174
# Block 100: chosen codeword index = 3551
# Block 101: chosen codeword index = 51839
# Block 102: chosen codeword index = 523
# Block 103: chosen codeword index = 222
# Block 104: chosen codeword index = 2385
# Block 105: chosen codeword index = 726
# Block 106: chosen codeword index = 92
# Block 107: chosen codeword index = 10613
# Block 108: chosen codeword index = 15
# Block 109: chosen codeword index = 597
# Block 110: chosen codeword index = 1616
# Block 111: chosen codeword index = 5461
# Block 112: chosen codeword index = 47
# Block 113: chosen codeword index = 1248
# Block 114: chosen codeword index = 389
# Block 115: chosen codeword index = 646
# Block 116: chosen codeword index = 3827
# Block 117: chosen codeword index = 1434
# Block 118: chosen codeword index = 870
# Block 119: chosen codeword index = 3159
# Block 120: chosen codeword index = 167
# Block 121: chosen codeword index = 424
# Block 122: chosen codeword index = 74835
# Block 123: chosen codeword index = 1168
# Block 124: chosen codeword index = 1831
# Block 125: chosen codeword index = 7325
# Block 126: chosen codeword index = 1943
# Block 127: chosen codeword index = 1145
# Block 128: chosen codeword index = 53
# Block 129: chosen codeword index = 1579
# Block 130: chosen codeword index = 927
# Block 131: chosen codeword index = 527
# Block 132: chosen codeword index = 2555
# Block 133: chosen codeword index = 1409
# Block 134: chosen codeword index = 762
# Block 135: chosen codeword index = 31
# Block 136: chosen codeword index = 5100
# Block 137: chosen codeword index = 885
# Block 138: chosen codeword index = 587
# Block 139: chosen codeword index = 1550
# Block 140: chosen codeword index = 4022
# Block 141: chosen codeword index = 807
# Block 142: chosen codeword index = 357
# Block 143: chosen codeword index = 161
# Block 144: chosen codeword index = 18064
# Block 145: chosen codeword index = 414
# Block 146: chosen codeword index = 1534
# Block 147: chosen codeword index = 841
# Block 148: chosen codeword index = 820
# Block 149: chosen codeword index = 4797
# Block 150: chosen codeword index = 5348
# Block 151: chosen codeword index = 1418
# Block 152: chosen codeword index = 99
# Block 153: chosen codeword index = 2735
# Block 154: chosen codeword index = 140
# Block 155: chosen codeword index = 0
# Block 156: chosen codeword index = 800
# Block 157: chosen codeword index = 106
# Block 158: chosen codeword index = 961
# Block 159: chosen codeword index = 6448
# Block 160: chosen codeword index = 3
# Block 161: chosen codeword index = 2439
# Block 162: chosen codeword index = 58
# Block 163: chosen codeword index = 1761
# Block 164: chosen codeword index = 347
# Block 165: chosen codeword index = 15032
# Block 166: chosen codeword index = 901
# Block 167: chosen codeword index = 1095
# Block 168: chosen codeword index = 3216
# Block 169: chosen codeword index = 5498
# Block 170: chosen codeword index = 791
# Block 171: chosen codeword index = 5044
# Block 172: chosen codeword index = 82
# Block 173: chosen codeword index = 51
# Block 174: chosen codeword index = 1720
# Block 175: chosen codeword index = 37
# Block 176: chosen codeword index = 1212
# Block 177: chosen codeword index = 322
# Block 178: chosen codeword index = 666
# Block 179: chosen codeword index = 3087
# Block 180: chosen codeword index = 437
# Block 181: chosen codeword index = 11294
# Block 182: chosen codeword index = 548
# Block 183: chosen codeword index = 5071
# Block 184: chosen codeword index = 485
# Block 185: chosen codeword index = 2609
# Block 186: chosen codeword index = 1104
# Block 187: chosen codeword index = 8438
# Block 188: chosen codeword index = 2247
# Block 189: chosen codeword index = 873
# Block 190: chosen codeword index = 1267
# Block 191: chosen codeword index = 131
# Block 192: chosen codeword index = 4
# Block 193: chosen codeword index = 0
# Block 194: chosen codeword index = 983
# Block 195: chosen codeword index = 1092
# Block 196: chosen codeword index = 1133
# Block 197: chosen codeword index = 1032
# Block 198: chosen codeword index = 2834
# Block 199: chosen codeword index = 208
# Block 200: chosen codeword index = 84
# Block 201: chosen codeword index = 1169
# Block 202: chosen codeword index = 804
# Block 203: chosen codeword index = 2226
# Block 204: chosen codeword index = 63
# Block 205: chosen codeword index = 111922
# Block 206: chosen codeword index = 52693
# Block 207: chosen codeword index = 201
# Block 208: chosen codeword index = 18150
# Block 209: chosen codeword index = 3738
# Block 210: chosen codeword index = 3089
# Block 211: chosen codeword index = 943
# Block 212: chosen codeword index = 1076
# Block 213: chosen codeword index = 102
# Block 214: chosen codeword index = 6161
# Block 215: chosen codeword index = 385
# Block 216: chosen codeword index = 2399
# Block 217: chosen codeword index = 730
# Block 218: chosen codeword index = 2558
# Block 219: chosen codeword index = 295
# Block 220: chosen codeword index = 1451
# Block 221: chosen codeword index = 1238
# Block 222: chosen codeword index = 1405
# Block 223: chosen codeword index = 3634
# Block 224: chosen codeword index = 532
# Block 225: chosen codeword index = 605
# Block 226: chosen codeword index = 34525
# Block 227: chosen codeword index = 4896
# Block 228: chosen codeword index = 2876
# Block 229: chosen codeword index = 287
# Block 230: chosen codeword index = 13088
# Block 231: chosen codeword index = 3272
# Block 232: chosen codeword index = 2247
# Block 233: chosen codeword index = 1908
# Block 234: chosen codeword index = 1949
# Block 235: chosen codeword index = 243
# Block 236: chosen codeword index = 23278
# Block 237: chosen codeword index = 2072
# Block 238: chosen codeword index = 3482
# Block 239: chosen codeword index = 832
# Block 240: chosen codeword index = 1143
# Block 241: chosen codeword index = 429
# Block 242: chosen codeword index = 2182
# Block 243: chosen codeword index = 527
# Block 244: chosen codeword index = 2240
# Block 245: chosen codeword index = 1866
# Block 246: chosen codeword index = 1130
# Block 247: chosen codeword index = 5175
# Block 248: chosen codeword index = 107
# Block 249: chosen codeword index = 1749
# Block 250: chosen codeword index = 513
# Block 251: chosen codeword index = 1497
# Block 252: chosen codeword index = 899
# Block 253: chosen codeword index = 316
# Block 254: chosen codeword index = 23
# Block 255: chosen codeword index = 1466
# Block 256: chosen codeword index = 954
# Block 257: chosen codeword index = 27
# Block 258: chosen codeword index = 15164
# Block 259: chosen codeword index = 379
# Block 260: chosen codeword index = 320
# Block 261: chosen codeword index = 1954
# Block 262: chosen codeword index = 3323
# Block 263: chosen codeword index = 57
# Block 264: chosen codeword index = 2661
# Block 265: chosen codeword index = 3040
# Block 266: chosen codeword index = 82
# Block 267: chosen codeword index = 872
# Block 268: chosen codeword index = 723
# Block 269: chosen codeword index = 1426
# Block 270: chosen codeword index = 473
# Block 271: chosen codeword index = 2962
# Block 272: chosen codeword index = 996
# Block 273: chosen codeword index = 2863
# Block 274: chosen codeword index = 2260
# Block 275: chosen codeword index = 1218
# Block 276: chosen codeword index = 32888
# Block 277: chosen codeword index = 1654
# Block 278: chosen codeword index = 1104
# Block 279: chosen codeword index = 645
# Block 280: chosen codeword index = 1249
# Block 281: chosen codeword index = 11898
# Block 282: chosen codeword index = 498
# Block 283: chosen codeword index = 756
# Block 284: chosen codeword index = 30665
# Block 285: chosen codeword index = 587
# Block 286: chosen codeword index = 102
# Block 287: chosen codeword index = 343
# Block 288: chosen codeword index = 4809
# Block 289: chosen codeword index = 0
# Block 290: chosen codeword index = 730
# Block 291: chosen codeword index = 652
# Block 292: chosen codeword index = 542
# Block 293: chosen codeword index = 3028
# Block 294: chosen codeword index = 6182
# Block 295: chosen codeword index = 2398
# Block 296: chosen codeword index = 18637
# Block 297: chosen codeword index = 1376
# Block 298: chosen codeword index = 1097
# Block 299: chosen codeword index = 3388
# Block 300: chosen codeword index = 1612
# Block 301: chosen codeword index = 870
# Block 302: chosen codeword index = 1093
# Block 303: chosen codeword index = 1281
# Block 304: chosen codeword index = 2172
# Block 305: chosen codeword index = 2340
# Block 306: chosen codeword index = 2461
# Block 307: chosen codeword index = 1364
# Block 308: chosen codeword index = 521
# Block 309: chosen codeword index = 724
# Block 310: chosen codeword index = 923
# Block 311: chosen codeword index = 3618
# Block 312: chosen codeword index = 488
# Block 313: chosen codeword index = 340
# Block 314: chosen codeword index = 1317
# Block 315: chosen codeword index = 1979
# Block 316: chosen codeword index = 834
# Block 317: chosen codeword index = 488
# Block 318: chosen codeword index = 128
# Block 319: chosen codeword index = 174
# Block 320: chosen codeword index = 1519
# Block 321: chosen codeword index = 1065
# Block 322: chosen codeword index = 663
# Block 323: chosen codeword index = 1137
# Block 324: chosen codeword index = 3252
# Block 325: chosen codeword index = 1783
# Block 326: chosen codeword index = 3355
# Block 327: chosen codeword index = 1387
# Block 328: chosen codeword index = 746
# Block 329: chosen codeword index = 1020
# Block 330: chosen codeword index = 4076
# Block 331: chosen codeword index = 571
# Block 332: chosen codeword index = 15
# Block 333: chosen codeword index = 1069
# Block 334: chosen codeword index = 1291
# Block 335: chosen codeword index = 251
# Block 336: chosen codeword index = 1576
# Block 337: chosen codeword index = 863
# Block 338: chosen codeword index = 3065
# Block 339: chosen codeword index = 250
# Block 340: chosen codeword index = 158
# Block 341: chosen codeword index = 201
# Block 342: chosen codeword index = 4238
# Block 343: chosen codeword index = 218
# Block 344: chosen codeword index = 2643
# Block 345: chosen codeword index = 708
# Block 346: chosen codeword index = 959
# Block 347: chosen codeword index = 924
# Block 348: chosen codeword index = 273
# Block 349: chosen codeword index = 1632
# Block 350: chosen codeword index = 9333
# Block 351: chosen codeword index = 1507
# Block 352: chosen codeword index = 83
# Block 353: chosen codeword index = 458
# Block 354: chosen codeword index = 39
# Block 355: chosen codeword index = 3192
# Block 356: chosen codeword index = 1176
# Block 357: chosen codeword index = 387
# Block 358: chosen codeword index = 1681
# Block 359: chosen codeword index = 3047
# Block 360: chosen codeword index = 1274
# Block 361: chosen codeword index = 3575
# Block 362: chosen codeword index = 897
# Block 363: chosen codeword index = 557
# Block 364: chosen codeword index = 413
# Block 365: chosen codeword index = 5370
# Block 366: chosen codeword index = 162
# Block 367: chosen codeword index = 594
# Block 368: chosen codeword index = 1146
# Block 369: chosen codeword index = 3054
# Block 370: chosen codeword index = 2293
# Block 371: chosen codeword index = 3629
# Block 372: chosen codeword index = 901
# Block 373: chosen codeword index = 515
# Block 374: chosen codeword index = 323
# Block 375: chosen codeword index = 4289
# Block 376: chosen codeword index = 181
# Block 377: chosen codeword index = 189
# Block 378: chosen codeword index = 937
# Block 379: chosen codeword index = 2596
# Block 380: chosen codeword index = 2000
# Block 381: chosen codeword index = 2676
# Block 382: chosen codeword index = 760
# Block 383: chosen codeword index = 597378
# Block 384: chosen codeword index = 16757
# Block 385: chosen codeword index = 4037
# Block 386: chosen codeword index = 1250
# Block 387: chosen codeword index = 2383
# Block 388: chosen codeword index = 55
# Block 389: chosen codeword index = 1434
# Block 390: chosen codeword index = 1190
# Block 391: chosen codeword index = 2795
# Block 392: chosen codeword index = 822
# Block 393: chosen codeword index = 3103
# Block 394: chosen codeword index = 271
# Block 395: chosen codeword index = 1211
# Block 396: chosen codeword index = 239
# Block 397: chosen codeword index = 2855
# Block 398: chosen codeword index = 724
# Block 399: chosen codeword index = 1153
# Block 400: chosen codeword index = 799
# Block 401: chosen codeword index = 2568
# Block 402: chosen codeword index = 317
# Block 403: chosen codeword index = 59095
# Block 404: chosen codeword index = 266
# Block 405: chosen codeword index = 648
# Block 406: chosen codeword index = 710
# Block 407: chosen codeword index = 125
# Block 408: chosen codeword index = 2323
# Block 409: chosen codeword index = 4457
# Block 410: chosen codeword index = 2866
# Block 411: chosen codeword index = 5467
# Block 412: chosen codeword index = 235
# Block 413: chosen codeword index = 2190
# Block 414: chosen codeword index = 363
# Block 415: chosen codeword index = 180
# Block 416: chosen codeword index = 3795
# Block 417: chosen codeword index = 3337
# Block 418: chosen codeword index = 225
# Block 419: chosen codeword index = 1003
# Block 420: chosen codeword index = 2443
# Block 421: chosen codeword index = 641
# Block 422: chosen codeword index = 1323
# Block 423: chosen codeword index = 1389
# Block 424: chosen codeword index = 859
# Block 425: chosen codeword index = 413
# Block 426: chosen codeword index = 1658
# Block 427: chosen codeword index = 1767
# Block 428: chosen codeword index = 764
# Block 429: chosen codeword index = 229
# Block 430: chosen codeword index = 1284
# Block 431: chosen codeword index = 3168
# Block 432: chosen codeword index = 614
# Block 433: chosen codeword index = 1045
# Block 434: chosen codeword index = 1235
# Block 435: chosen codeword index = 3225
# Block 436: chosen codeword index = 1465
# Block 437: chosen codeword index = 4470
# Block 438: chosen codeword index = 1529
# Block 439: chosen codeword index = 925
# Block 440: chosen codeword index = 2232
# Block 441: chosen codeword index = 1705
# Block 442: chosen codeword index = 82911
# Block 443: chosen codeword index = 1636
# Block 444: chosen codeword index = 68779
# Block 445: chosen codeword index = 2177
# Block 446: chosen codeword index = 237
# Block 447: chosen codeword index = 2032
# Block 448: chosen codeword index = 899
# Block 449: chosen codeword index = 28551
# Block 450: chosen codeword index = 877
# Block 451: chosen codeword index = 739
# Block 452: chosen codeword index = 250
# Block 453: chosen codeword index = 2724
# Block 454: chosen codeword index = 547
# Block 455: chosen codeword index = 2611
# Block 456: chosen codeword index = 57
# Block 457: chosen codeword index = 7909
# Block 458: chosen codeword index = 2586
# Block 459: chosen codeword index = 284
# Block 460: chosen codeword index = 3291
# Block 461: chosen codeword index = 256
# Block 462: chosen codeword index = 182
# Block 463: chosen codeword index = 2006
# Block 464: chosen codeword index = 832
# Block 465: chosen codeword index = 216
# Block 466: chosen codeword index = 368
# Block 467: chosen codeword index = 4374
# Block 468: chosen codeword index = 326
# Block 469: chosen codeword index = 672
# Block 470: chosen codeword index = 609
# Block 471: chosen codeword index = 508
# Block 472: chosen codeword index = 2599
# Block 473: chosen codeword index = 2332
# Block 474: chosen codeword index = 556
# Block 475: chosen codeword index = 2292
# Block 476: chosen codeword index = 1302
# Block 477: chosen codeword index = 276
# Block 478: chosen codeword index = 936
# Block 479: chosen codeword index = 160
# Block 480: chosen codeword index = 144
# Block 481: chosen codeword index = 4891
# Block 482: chosen codeword index = 703
# Block 483: chosen codeword index = 21
# Block 484: chosen codeword index = 2726
# Block 485: chosen codeword index = 148
# Block 486: chosen codeword index = 465
# Block 487: chosen codeword index = 829
# Block 488: chosen codeword index = 358
# Block 489: chosen codeword index = 2590
# Block 490: chosen codeword index = 329
# Block 491: chosen codeword index = 4121
# Block 492: chosen codeword index = 3458
# Block 493: chosen codeword index = 4485
# Block 494: chosen codeword index = 1960
# Block 495: chosen codeword index = 16422
# Block 496: chosen codeword index = 1491
# Block 497: chosen codeword index = 2470
# Block 498: chosen codeword index = 29128
# Block 499: chosen codeword index = 2312
# Block 500: chosen codeword index = 413
# Block 501: chosen codeword index = 1788
# Block 502: chosen codeword index = 1254
# Block 503: chosen codeword index = 3422
# Block 504: chosen codeword index = 4
# Block 505: chosen codeword index = 1961
# Block 506: chosen codeword index = 3410
# Block 507: chosen codeword index = 222
# Block 508: chosen codeword index = 300
# Block 509: chosen codeword index = 352
# Block 510: chosen codeword index = 141
# Block 511: chosen codeword index = 440
# Block 512: chosen codeword index = 44
# Block 513: chosen codeword index = 1945
# Block 514: chosen codeword index = 4137
# Block 515: chosen codeword index = 1356
# Block 516: chosen codeword index = 285
# Block 517: chosen codeword index = 1516
# Block 518: chosen codeword index = 364284
# Block 519: chosen codeword index = 620
# Block 520: chosen codeword index = 1646
# Block 521: chosen codeword index = 3562
# Block 522: chosen codeword index = 13591
# Block 523: chosen codeword index = 183
# Block 524: chosen codeword index = 1351
# Block 525: chosen codeword index = 1065
# Block 526: chosen codeword index = 28515
# Block 527: chosen codeword index = 316
# Block 528: chosen codeword index = 847
# Block 529: chosen codeword index = 1142
# Block 530: chosen codeword index = 1044
# Block 531: chosen codeword index = 1268
# Block 532: chosen codeword index = 560
# Block 533: chosen codeword index = 1166
# Block 534: chosen codeword index = 1605
# Block 535: chosen codeword index = 602
# Block 536: chosen codeword index = 2066
# Block 537: chosen codeword index = 4973
# Block 538: chosen codeword index = 676
# Block 539: chosen codeword index = 2882
# Block 540: chosen codeword index = 1587
# Block 541: chosen codeword index = 1263
# Block 542: chosen codeword index = 734
# Block 543: chosen codeword index = 1524
# Block 544: chosen codeword index = 573
# Block 545: chosen codeword index = 8496
# Block 546: chosen codeword index = 1053
# Block 547: chosen codeword index = 1870
# Block 548: chosen codeword index = 3306
# Block 549: chosen codeword index = 2319
# Block 550: chosen codeword index = 109573
# Block 551: chosen codeword index = 2024
# Block 552: chosen codeword index = 504
# Block 553: chosen codeword index = 35
# Block 554: chosen codeword index = 0
# Block 555: chosen codeword index = 1401
# Block 556: chosen codeword index = 713
# Block 557: chosen codeword index = 756
# Block 558: chosen codeword index = 20562
# Block 559: chosen codeword index = 1055
# Block 560: chosen codeword index = 2215
# Block 561: chosen codeword index = 1142
# Block 562: chosen codeword index = 492
# Block 563: chosen codeword index = 1784
# Block 564: chosen codeword index = 3956
# Block 565: chosen codeword index = 77
# Block 566: chosen codeword index = 28108
# Block 567: chosen codeword index = 212845
# Block 568: chosen codeword index = 1125
# Block 569: chosen codeword index = 1402
# Block 570: chosen codeword index = 1130
# Block 571: chosen codeword index = 1844
# Block 572: chosen codeword index = 238
# Block 573: chosen codeword index = 710
# Block 574: chosen codeword index = 37826
# Block 575: chosen codeword index = 839
# Block 576: chosen codeword index = 97
# Block 577: chosen codeword index = 3577
# Block 578: chosen codeword index = 1303
# Block 579: chosen codeword index = 42
# Block 580: chosen codeword index = 209
# Block 581: chosen codeword index = 338
# Block 582: chosen codeword index = 80478
# Block 583: chosen codeword index = 0
# Block 584: chosen codeword index = 1110
# Block 585: chosen codeword index = 7909
# Block 586: chosen codeword index = 730
# Block 587: chosen codeword index = 2416
# Block 588: chosen codeword index = 33845
# Block 589: chosen codeword index = 363
# Block 590: chosen codeword index = 19
# Block 591: chosen codeword index = 794
# Block 592: chosen codeword index = 1915
# Block 593: chosen codeword index = 2485
# Block 594: chosen codeword index = 795
# Block 595: chosen codeword index = 3394
# Block 596: chosen codeword index = 629
# Block 597: chosen codeword index = 299
# Block 598: chosen codeword index = 1812
# Block 599: chosen codeword index = 6077
# Block 600: chosen codeword index = 558
# Block 601: chosen codeword index = 3117
# Block 602: chosen codeword index = 1301
# Block 603: chosen codeword index = 2287
# Block 604: chosen codeword index = 1324
# Block 605: chosen codeword index = 219
# Block 606: chosen codeword index = 1984
# Block 607: chosen codeword index = 450
# Block 608: chosen codeword index = 1185
# Block 609: chosen codeword index = 301
# Block 610: chosen codeword index = 573
# Block 611: chosen codeword index = 1105
# Block 612: chosen codeword index = 595
# Block 613: chosen codeword index = 150
# Block 614: chosen codeword index = 404
# Block 615: chosen codeword index = 1057
# Block 616: chosen codeword index = 1579
# Block 617: chosen codeword index = 1906
# Block 618: chosen codeword index = 1549
# Block 619: chosen codeword index = 1588
# Block 620: chosen codeword index = 375
# Block 621: chosen codeword index = 3053
# Block 622: chosen codeword index = 304
# Block 623: chosen codeword index = 576
# Block 624: chosen codeword index = 3745
# Block 625: chosen codeword index = 882
# Block 626: chosen codeword index = 423
# Block 627: chosen codeword index = 978
# Block 628: chosen codeword index = 3574
# Block 629: chosen codeword index = 5241
# Block 630: chosen codeword index = 671
# Block 631: chosen codeword index = 1025
# Block 632: chosen codeword index = 2277
# Block 633: chosen codeword index = 1050
# Block 634: chosen codeword index = 14283
# Block 635: chosen codeword index = 1441
# Block 636: chosen codeword index = 1297
# Block 637: chosen codeword index = 1199
# Block 638: chosen codeword index = 223
# Block 639: chosen codeword index = 1020
# Block 640: chosen codeword index = 3959
# Block 641: chosen codeword index = 3476
# Block 642: chosen codeword index = 1654
# Block 643: chosen codeword index = 130354
# Block 644: chosen codeword index = 6021
# Block 645: chosen codeword index = 405
# Block 646: chosen codeword index = 2461
# Block 647: chosen codeword index = 50823
# Block 648: chosen codeword index = 3149
# Block 649: chosen codeword index = 4195
# Block 650: chosen codeword index = 2237
# Block 651: chosen codeword index = 1662
# Block 652: chosen codeword index = 380
# Block 653: chosen codeword index = 1027
# Block 654: chosen codeword index = 138
# Block 655: chosen codeword index = 1620
# Block 656: chosen codeword index = 1931
# Block 657: chosen codeword index = 5
# Block 658: chosen codeword index = 1781
# Block 659: chosen codeword index = 787
# Block 660: chosen codeword index = 1897
# Block 661: chosen codeword index = 2359
# Block 662: chosen codeword index = 5103
# Block 663: chosen codeword index = 769
# Block 664: chosen codeword index = 1684
# Block 665: chosen codeword index = 3657
# Block 666: chosen codeword index = 466
# Block 667: chosen codeword index = 1780
# Block 668: chosen codeword index = 394
# Block 669: chosen codeword index = 390
# Block 670: chosen codeword index = 1295
# Block 671: chosen codeword index = 763
# Block 672: chosen codeword index = 857
# Block 673: chosen codeword index = 6571
# Block 674: chosen codeword index = 1329
# Block 675: chosen codeword index = 4178
# Block 676: chosen codeword index = 1865
# Block 677: chosen codeword index = 4426
# Block 678: chosen codeword index = 2028
# Block 679: chosen codeword index = 165
# Block 680: chosen codeword index = 4639
# Block 681: chosen codeword index = 1657
# Block 682: chosen codeword index = 182
# Block 683: chosen codeword index = 3922
# Block 684: chosen codeword index = 14
# Block 685: chosen codeword index = 424
# Block 686: chosen codeword index = 586
# Block 687: chosen codeword index = 478
# Block 688: chosen codeword index = 586
# Block 689: chosen codeword index = 5199
# Block 690: chosen codeword index = 25649
# Block 691: chosen codeword index = 20367
# Block 692: chosen codeword index = 978
# Block 693: chosen codeword index = 11
# Block 694: chosen codeword index = 1779
# Block 695: chosen codeword index = 645
# Block 696: chosen codeword index = 626
# Block 697: chosen codeword index = 2806
# Block 698: chosen codeword index = 1892
# Block 699: chosen codeword index = 1718
# Block 700: chosen codeword index = 4788
# Block 701: chosen codeword index = 1726
# Block 702: chosen codeword index = 880
# Block 703: chosen codeword index = 4903
# Block 704: chosen codeword index = 669
# Block 705: chosen codeword index = 455
# Block 706: chosen codeword index = 503
# Block 707: chosen codeword index = 1593
# Block 708: chosen codeword index = 598
# Block 709: chosen codeword index = 6028
# Block 710: chosen codeword index = 1258
# Block 711: chosen codeword index = 6679
# Block 712: chosen codeword index = 33900
# Block 713: chosen codeword index = 394
# Block 714: chosen codeword index = 124
# Block 715: chosen codeword index = 452
# Block 716: chosen codeword index = 5236
# Block 717: chosen codeword index = 894
# Block 718: chosen codeword index = 3874
# Block 719: chosen codeword index = 839
# Block 720: chosen codeword index = 188
# Block 721: chosen codeword index = 2127
# Block 722: chosen codeword index = 1069
# Block 723: chosen codeword index = 712
# Block 724: chosen codeword index = 0
# Block 725: chosen codeword index = 775
# Block 726: chosen codeword index = 218
# Block 727: chosen codeword index = 1022
# Block 728: chosen codeword index = 919
# Block 729: chosen codeword index = 61
# Block 730: chosen codeword index = 885
# Block 731: chosen codeword index = 491
# Block 732: chosen codeword index = 2726
# Block 733: chosen codeword index = 2297
# Block 734: chosen codeword index = 441
# Block 735: chosen codeword index = 112
# Block 736: chosen codeword index = 1061
# Block 737: chosen codeword index = 1093
# Block 738: chosen codeword index = 48565
# Block 739: chosen codeword index = 7578
# Block 740: chosen codeword index = 2484
# Block 741: chosen codeword index = 31
# Block 742: chosen codeword index = 2862
# Block 743: chosen codeword index = 1526
# Block 744: chosen codeword index = 665
# Block 745: chosen codeword index = 301
# Block 746: chosen codeword index = 169
# Block 747: chosen codeword index = 4301
# Block 748: chosen codeword index = 3396
# Block 749: chosen codeword index = 2354
# Block 750: chosen codeword index = 33
# Block 751: chosen codeword index = 966
# Block 752: chosen codeword index = 4958
# Block 753: chosen codeword index = 278
# Block 754: chosen codeword index = 148
# Block 755: chosen codeword index = 1033
# Block 756: chosen codeword index = 5832
# Block 757: chosen codeword index = 585
# Block 758: chosen codeword index = 1561
# Block 759: chosen codeword index = 2155
# Block 760: chosen codeword index = 993
# Block 761: chosen codeword index = 3215
# Block 762: chosen codeword index = 1250
# Block 763: chosen codeword index = 1029
# Block 764: chosen codeword index = 1954
# Block 765: chosen codeword index = 16343
# Block 766: chosen codeword index = 1342
# Block 767: chosen codeword index = 601
# Block 768: chosen codeword index = 41
# Block 769: chosen codeword index = 807
# Block 770: chosen codeword index = 1846
# Block 771: chosen codeword index = 1813
# Block 772: chosen codeword index = 645
# Block 773: chosen codeword index = 0
# Block 774: chosen codeword index = 1425
# Block 775: chosen codeword index = 89
# Block 776: chosen codeword index = 472
# Block 777: chosen codeword index = 14
# Block 778: chosen codeword index = 0
# Block 779: chosen codeword index = 395
# Block 780: chosen codeword index = 74
# Block 781: chosen codeword index = 4
# Block 782: chosen codeword index = 63
# Block 783: chosen codeword index = 811
# Block 784: chosen codeword index = 179
# Block 785: chosen codeword index = 444
# Block 786: chosen codeword index = 1478
# Block 787: chosen codeword index = 812
# Block 788: chosen codeword index = 10401
# Block 789: chosen codeword index = 778
# Block 790: chosen codeword index = 1316
# Block 791: chosen codeword index = 687
# Block 792: chosen codeword index = 482
# Block 793: chosen codeword index = 1357
# Block 794: chosen codeword index = 743
# Block 795: chosen codeword index = 5479
# Block 796: chosen codeword index = 326
# Block 797: chosen codeword index = 2749
# Block 798: chosen codeword index = 446
# Block 799: chosen codeword index = 457
# Block 800: chosen codeword index = 907
# Block 801: chosen codeword index = 525
# Block 802: chosen codeword index = 284
# Block 803: chosen codeword index = 232
# Block 804: chosen codeword index = 1427
# Block 805: chosen codeword index = 1927
# Block 806: chosen codeword index = 179658
# Block 807: chosen codeword index = 63
# Block 808: chosen codeword index = 1195
# Block 809: chosen codeword index = 183
# Block 810: chosen codeword index = 50
# Block 811: chosen codeword index = 542
# Block 812: chosen codeword index = 1032
# Block 813: chosen codeword index = 279
# Block 814: chosen codeword index = 271
# Block 815: chosen codeword index = 1205
# Block 816: chosen codeword index = 1864
# Block 817: chosen codeword index = 4078
# Block 818: chosen codeword index = 3805
# Block 819: chosen codeword index = 272
# Block 820: chosen codeword index = 714
# Block 821: chosen codeword index = 0
# Block 822: chosen codeword index = 1430
# Block 823: chosen codeword index = 66
# Block 824: chosen codeword index = 1297
# Block 825: chosen codeword index = 1581
# Block 826: chosen codeword index = 586
# Block 827: chosen codeword index = 3015
# Block 828: chosen codeword index = 2789
# Block 829: chosen codeword index = 72
# Block 830: chosen codeword index = 1746
# Block 831: chosen codeword index = 1319
# Block 832: chosen codeword index = 707
# Block 833: chosen codeword index = 289
# Block 834: chosen codeword index = 7266
# Block 835: chosen codeword index = 1226
# Block 836: chosen codeword index = 609
# Block 837: chosen codeword index = 6217
# Block 838: chosen codeword index = 9661
# Block 839: chosen codeword index = 407
# Block 840: chosen codeword index = 626
# Block 841: chosen codeword index = 881
# Block 842: chosen codeword index = 110
# Block 843: chosen codeword index = 395
# Block 844: chosen codeword index = 111
# Block 845: chosen codeword index = 341
# Block 846: chosen codeword index = 3293
# Block 847: chosen codeword index = 2874
# Block 848: chosen codeword index = 481
# Block 849: chosen codeword index = 1592
# Block 850: chosen codeword index = 3139
# Block 851: chosen codeword index = 3187
# Block 852: chosen codeword index = 8827
# Block 853: chosen codeword index = 268
# Block 854: chosen codeword index = 772
# Block 855: chosen codeword index = 411
# Block 856: chosen codeword index = 599
# Block 857: chosen codeword index = 4222
# Block 858: chosen codeword index = 2354
# Block 859: chosen codeword index = 6457
# Block 860: chosen codeword index = 1504
# Block 861: chosen codeword index = 358
# Block 862: chosen codeword index = 2069
# Block 863: chosen codeword index = 3215
# Block 864: chosen codeword index = 134
# Block 865: chosen codeword index = 4387
# Block 866: chosen codeword index = 343
# Block 867: chosen codeword index = 1894
# Block 868: chosen codeword index = 1659
# Block 869: chosen codeword index = 2987
# Block 870: chosen codeword index = 693
# Block 871: chosen codeword index = 2241
# Block 872: chosen codeword index = 476
# Block 873: chosen codeword index = 2292
# Block 874: chosen codeword index = 734
# Block 875: chosen codeword index = 761
# Block 876: chosen codeword index = 706
# Block 877: chosen codeword index = 2229
# Block 878: chosen codeword index = 359
# Block 879: chosen codeword index = 656
# Block 880: chosen codeword index = 514
# Block 881: chosen codeword index = 1413
# Block 882: chosen codeword index = 2365
# Block 883: chosen codeword index = 2436
# Block 884: chosen codeword index = 19
# Block 885: chosen codeword index = 4060
# Block 886: chosen codeword index = 748
# Block 887: chosen codeword index = 494
# Block 888: chosen codeword index = 202
# Block 889: chosen codeword index = 185
# Block 890: chosen codeword index = 3537
# Block 891: chosen codeword index = 1076
# Block 892: chosen codeword index = 1308
# Block 893: chosen codeword index = 708
# Block 894: chosen codeword index = 150
# Block 895: chosen codeword index = 1913
# Block 896: chosen codeword index = 6852
# Block 897: chosen codeword index = 1512
# Block 898: chosen codeword index = 1027
# Block 899: chosen codeword index = 351
# Block 900: chosen codeword index = 398
# Block 901: chosen codeword index = 0
# Block 902: chosen codeword index = 3326
# Block 903: chosen codeword index = 609
# Block 904: chosen codeword index = 381
# Block 905: chosen codeword index = 1099
# Block 906: chosen codeword index = 5248
# Block 907: chosen codeword index = 3392
# Block 908: chosen codeword index = 1705
# Block 909: chosen codeword index = 554
# Block 910: chosen codeword index = 724
# Block 911: chosen codeword index = 451
# Block 912: chosen codeword index = 881
# Block 913: chosen codeword index = 1151
# Block 914: chosen codeword index = 100
# Block 915: chosen codeword index = 4692
# Block 916: chosen codeword index = 1242
# Block 917: chosen codeword index = 538
# Block 918: chosen codeword index = 1418
# Block 919: chosen codeword index = 8350
# Block 920: chosen codeword index = 2854
# Block 921: chosen codeword index = 1467
# Block 922: chosen codeword index = 103
# Block 923: chosen codeword index = 6646
# Block 924: chosen codeword index = 121
# Block 925: chosen codeword index = 1055
# Block 926: chosen codeword index = 275
# Block 927: chosen codeword index = 2559
# Block 928: chosen codeword index = 1587
# Block 929: chosen codeword index = 4679
# Block 930: chosen codeword index = 386
# Block 931: chosen codeword index = 47
# Block 932: chosen codeword index = 7105
# Block 933: chosen codeword index = 603
# Block 934: chosen codeword index = 354
# Block 935: chosen codeword index = 1063
# Block 936: chosen codeword index = 37
# Block 937: chosen codeword index = 1280
# Block 938: chosen codeword index = 2707
# Block 939: chosen codeword index = 603
# Block 940: chosen codeword index = 616
# Block 941: chosen codeword index = 2962
# Block 942: chosen codeword index = 2057
# Block 943: chosen codeword index = 1315
# Block 944: chosen codeword index = 478
# Block 945: chosen codeword index = 1531
# Block 946: chosen codeword index = 417
# Block 947: chosen codeword index = 2508
# Block 948: chosen codeword index = 3491
# Block 949: chosen codeword index = 5399
# Block 950: chosen codeword index = 1542
# Block 951: chosen codeword index = 649
# Block 952: chosen codeword index = 2775
# Block 953: chosen codeword index = 212
# Block 954: chosen codeword index = 4015
# Block 955: chosen codeword index = 1553
# Block 956: chosen codeword index = 2412
# Block 957: chosen codeword index = 479
# Block 958: chosen codeword index = 1022
# Block 959: chosen codeword index = 918
# Block 960: chosen codeword index = 18978
# Block 961: chosen codeword index = 1947
# Block 962: chosen codeword index = 454
# Block 963: chosen codeword index = 7663
# Block 964: chosen codeword index = 7319
# Block 965: chosen codeword index = 88
# Block 966: chosen codeword index = 629
# Block 967: chosen codeword index = 741
# Block 968: chosen codeword index = 189
# Block 969: chosen codeword index = 484
# Block 970: chosen codeword index = 712
# Block 971: chosen codeword index = 182
# Block 972: chosen codeword index = 340
# Block 973: chosen codeword index = 225
# Block 974: chosen codeword index = 2721
# Block 975: chosen codeword index = 1692
# Block 976: chosen codeword index = 308
# Block 977: chosen codeword index = 18
# Block 978: chosen codeword index = 35076
# Block 979: chosen codeword index = 835
# Block 980: chosen codeword index = 1170
# Block 981: chosen codeword index = 2643
# Block 982: chosen codeword index = 502
# Block 983: chosen codeword index = 1098
# Block 984: chosen codeword index = 4257
# Block 985: chosen codeword index = 1672
# Block 986: chosen codeword index = 227
# Block 987: chosen codeword index = 951
# Block 988: chosen codeword index = 14030
# Block 989: chosen codeword index = 1978
# Block 990: chosen codeword index = 783
# Block 991: chosen codeword index = 811
# Block 992: chosen codeword index = 1619
# Block 993: chosen codeword index = 1329
# Block 994: chosen codeword index = 6
# Block 995: chosen codeword index = 314
# Block 996: chosen codeword index = 1092
# Block 997: chosen codeword index = 311
# Block 998: chosen codeword index = 235
# Block 999: chosen codeword index = 16
# eps= 0.25  Error source count =   10

# %%
print("eps=0.11, Error source count =  483")
print("eps=0.15, Error source count =  217")
print("eps= 0.2  Error source count =   66")
