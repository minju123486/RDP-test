# %%
import numpy as np
X = [0,1] # source
px = [1/2, 1/2] # source
X_hat = [0,1]
pX_hat = [1/2, 1/2]
X_HatcoditionedX = [[0,1],[0,1]]
pX_HatcoditionedX = [[0.67, 0.33], [0.33, 0.67]]
pXY = [[0.335, 0.165],[0.165, 0.335]]

# %%
def Hamming_distortion(X, Xhat):
    assert X.shape == Xhat.shape, "X와 Xhat shape이 다름"
    mism = (X != Xhat)
    cnt = np.count_nonzero(mism)
    return cnt

# %%
import numpy as np

def random_bit(size=None):
    return np.random.randint(0, 2, size=size)

print(random_bit())          # 단일 0 또는 1
print(random_bit(10))        # [0 1 0 1 1 0 0 1 0 1]
# Out:
# 1
# [0 1 0 0 0 1 1 1 1 1]

# %%
import math
def mutual_information(X,Xhat):
    hap = 0
    for x in X:
        for x_hat in X_hat:
            hap += (px[x] * pX_HatcoditionedX[x_hat][x] * 
                    math.log2(px[x] * pX_HatcoditionedX[x_hat][x]/(px[x]*
                                                                pX_hat[x_hat]))
                   )
    return hap

# %%
mutual_information(X, X_hat)
# Out:
# 0.08507362722027256

# %%
import numpy as np

#조건부 분포 검증

# 정의
X_vals = np.array([0, 1])
pX = np.array([0.5, 0.5])
pX_hat = np.array([0.5, 0.5])
pXhat_given_X = np.array([[0.67, 0.33],
                          [0.33, 0.67]]) 

# 샘플 수
N = 100_000

# 1. X 샘플링 (Bern(1/2))
X_samples = np.random.choice(X_vals, size=N, p=pX)

# 2. X_hat 샘플링 (조건부 분포 이용)
Xhat_samples = np.empty(N, dtype=int)
for i, x in enumerate(X_samples):
    Xhat_samples[i] = np.random.choice(X_vals, p=pXhat_given_X[x])

# 3. joint 빈도 및 왜곡 확인
joint_counts = np.zeros((2, 2))
for x, xhat in zip(X_samples, Xhat_samples):
    joint_counts[x, xhat] += 1
joint_probs = joint_counts / N

# 4. 평균 왜곡 (해밍)
distortion = np.mean(X_samples != Xhat_samples)

print("Joint empirical p(x, x̂):")
print(joint_probs)
print(f"평균 왜곡 ≈ {distortion:.3f}")
# Out:
# Joint empirical p(x, x̂):
# [[0.33472 0.16285]
#  [0.165   0.33743]]
# 평균 왜곡 ≈ 0.328

# %%
Xhat_samples
# Out:
# array([1, 0, 0, ..., 1, 0, 0])

# %%
def codebook_generation(n, R, distribution):
    M = int(2 ** (n*R))
    codebook = np.random.choice([0, 1], size=(M, n), p=distribution)
    return codebook

# %%
n=150
R=0.11
codebook = codebook_generation(n, R, pX_hat)
codebook.shape
np.sum(codebook, axis = 1).shape
# Out:
# (92681,)

# %%
count = 1
for i in range(count):
    xn = random_bit(n)

# %%
def joint_empirical_pmf(x_seq: np.ndarray, y_seq: np.ndarray, X_alphabet, Y_alphabet):
    x_seq = np.asarray(x_seq)                     # 예: array([0,1,1,0])
    y_seq = np.asarray(y_seq)                     # 예: array([0,1,1,0])
    assert x_seq.shape == y_seq.shape and x_seq.ndim == 1

    # map symbols to indices
    x_to_idx = {sym:i for i, sym in enumerate(X_alphabet)}   # {0:0, 1:1}
    y_to_idx = {sym:j for j, sym in enumerate(Y_alphabet)}   # {0:0, 1:1}
    kx, ky = len(X_alphabet), len(Y_alphabet)                # kx=2, ky=2

    # encode to indices
    xi = np.vectorize(x_to_idx.__getitem__)(x_seq)           # [0,1,1,0]
    yj = np.vectorize(y_to_idx.__getitem__)(y_seq)           # [0,1,1,0]
    # joint counts
    idx = xi * ky + yj                                       
    # ky=2 이므로 xi*2 + yj → [0*2+0, 1*2+1, 1*2+1, 0*2+0] = [0,3,3,0]

    counts = np.bincount(idx, minlength=kx*ky).astype(float).reshape(kx, ky)
    # idx=[0,3,3,0] 이므로 bincount: [2,0,0,2] → reshape(2x2)=[[2,0],[0,2]]
    return counts / x_seq.size 
    # x_seq.size = 4 → [[2/4, 0/4],[0/4, 2/4]]
    # 결과: array([[0.5, 0.0], [0.0, 0.5]])

# %%
def is_jointly_typical(x_seq,
                       y_seq,
                       pXY,
                       X_alphabet,
                       Y_alphabet,
                       eps: float):
    """
    (x^n, y^n)이 주어졌을 때,
    정의:
      |π(x,y) - pXY(x,y)| <= eps * pXY(x,y)  (pXY(x,y) > 0인 모든 (x,y))
    이고,
      pXY(x,y) = 0 인 자리에서는 π(x,y)도 0 이어야 함
    을 만족하면 True (joint ε-typical), 아니면 False.
    """
    # 경험적 joint pmf π(x,y)
    pi = joint_empirical_pmf(x_seq, y_seq, X_alphabet, Y_alphabet)

    # 이론 joint pmf
    pXY = np.asarray(pXY, dtype=float)
    assert pi.shape == pXY.shape, "π와 pXY의 shape이 다릅니다."

    # (1) pXY(x,y) > 0 인 위치: 상대 오차 조건 검사
    pos = pXY > 0
    if np.any(np.abs(pi[pos] - pXY[pos]) > eps * pXY[pos]):
        return False

    # (2) pXY(x,y) = 0 인 위치: 실제로도 안 나와야 함
    zero = ~pos
    if np.any(pi[zero] > 0):
        return False

    return True

# %%
N=100000
joint_empirical_pmf(np.random.choice(X_vals, size=N,p=px),np.random.choice(X_vals,  size=N,p=pX_hat),X,X_hat)
# Out:
# <class 'numpy.ndarray'>
# array([[0.24743, 0.25185],
#        [0.25098, 0.24974]])

# %%
count = 1000
zero_cnt = 0
for i in range(count):
    xn = random_bit(n)  # source block X^n
    found_index = None
    for idx, tempt in enumerate(codebook):   # tempt = codeword candidate
        if is_jointly_typical(xn, tempt, pXY, X, X_hat, eps=0.15):
            found_index = idx
            break

    if found_index is None:
        found_index = 0  # 못 찾았을 때 기본값 (논문에서 m=1)
        zero_cnt += 1
    print(f"Block {i}: chosen codeword index = {found_index}")
print("Error source count = ", zero_cnt)
# Out:
# Block 0: chosen codeword index = 14335
# Block 1: chosen codeword index = 657
# Block 2: chosen codeword index = 1963
# Block 3: chosen codeword index = 10307
# Block 4: chosen codeword index = 0
# Block 5: chosen codeword index = 4527
# Block 6: chosen codeword index = 7907
# Block 7: chosen codeword index = 0
# Block 8: chosen codeword index = 2995
# Block 9: chosen codeword index = 2089
# Block 10: chosen codeword index = 4202
# Block 11: chosen codeword index = 4449
# Block 12: chosen codeword index = 1051
# Block 13: chosen codeword index = 8099
# Block 14: chosen codeword index = 0
# Block 15: chosen codeword index = 15175
# Block 16: chosen codeword index = 15301
# Block 17: chosen codeword index = 1326
# Block 18: chosen codeword index = 20906
# Block 19: chosen codeword index = 6475
# Block 20: chosen codeword index = 13129
# Block 21: chosen codeword index = 0
# Block 22: chosen codeword index = 734
# Block 23: chosen codeword index = 3267
# Block 24: chosen codeword index = 26315
# Block 25: chosen codeword index = 0
# Block 26: chosen codeword index = 0
# Block 27: chosen codeword index = 15516
# Block 28: chosen codeword index = 3502
# Block 29: chosen codeword index = 2808
# Block 30: chosen codeword index = 29503
# Block 31: chosen codeword index = 16526
# Block 32: chosen codeword index = 0
# Block 33: chosen codeword index = 625
# Block 34: chosen codeword index = 0
# Block 35: chosen codeword index = 7706
# Block 36: chosen codeword index = 22696
# Block 37: chosen codeword index = 8254
# Block 38: chosen codeword index = 89465
# Block 39: chosen codeword index = 2501
# Block 40: chosen codeword index = 4270
# Block 41: chosen codeword index = 9204
# Block 42: chosen codeword index = 6004
# Block 43: chosen codeword index = 0
# Block 44: chosen codeword index = 12675
# Block 45: chosen codeword index = 1608
# Block 46: chosen codeword index = 1337
# Block 47: chosen codeword index = 58895
# Block 48: chosen codeword index = 4219
# Block 49: chosen codeword index = 3137
# Block 50: chosen codeword index = 5509
# Block 51: chosen codeword index = 0
# Block 52: chosen codeword index = 47017
# Block 53: chosen codeword index = 52183
# Block 54: chosen codeword index = 40895
# Block 55: chosen codeword index = 0
# Block 56: chosen codeword index = 79
# Block 57: chosen codeword index = 1942
# Block 58: chosen codeword index = 27241
# Block 59: chosen codeword index = 39619
# Block 60: chosen codeword index = 4249
# Block 61: chosen codeword index = 46262
# Block 62: chosen codeword index = 24465
# Block 63: chosen codeword index = 0
# Block 64: chosen codeword index = 2593
# Block 65: chosen codeword index = 45595
# Block 66: chosen codeword index = 22426
# Block 67: chosen codeword index = 0
# Block 68: chosen codeword index = 2210
# Block 69: chosen codeword index = 17562
# Block 70: chosen codeword index = 9661
# Block 71: chosen codeword index = 9150
# Block 72: chosen codeword index = 52713
# Block 73: chosen codeword index = 0
# Block 74: chosen codeword index = 54728
# Block 75: chosen codeword index = 42010
# Block 76: chosen codeword index = 2796
# Block 77: chosen codeword index = 6927
# Block 78: chosen codeword index = 33506
# Block 79: chosen codeword index = 12683
# Block 80: chosen codeword index = 25108
# Block 81: chosen codeword index = 2301
# Block 82: chosen codeword index = 8000
# Block 83: chosen codeword index = 0
# Block 84: chosen codeword index = 2382
# Block 85: chosen codeword index = 62053
# Block 86: chosen codeword index = 4754
# Block 87: chosen codeword index = 21498
# Block 88: chosen codeword index = 10815
# Block 89: chosen codeword index = 7002
# Block 90: chosen codeword index = 10961
# Block 91: chosen codeword index = 22984
# Block 92: chosen codeword index = 38956
# Block 93: chosen codeword index = 13240
# Block 94: chosen codeword index = 24264
# Block 95: chosen codeword index = 0
# Block 96: chosen codeword index = 0
# Block 97: chosen codeword index = 11105
# Block 98: chosen codeword index = 2549
# Block 99: chosen codeword index = 8921
# Block 100: chosen codeword index = 8868
# Block 101: chosen codeword index = 4411
# Block 102: chosen codeword index = 70
# Block 103: chosen codeword index = 0
# Block 104: chosen codeword index = 21001
# Block 105: chosen codeword index = 11643
# Block 106: chosen codeword index = 0
# Block 107: chosen codeword index = 6445
# Block 108: chosen codeword index = 48816
# Block 109: chosen codeword index = 18775
# Block 110: chosen codeword index = 8223
# Block 111: chosen codeword index = 1674
# Block 112: chosen codeword index = 1104
# Block 113: chosen codeword index = 86774
# Block 114: chosen codeword index = 33143
# Block 115: chosen codeword index = 0
# Block 116: chosen codeword index = 5139
# Block 117: chosen codeword index = 0
# Block 118: chosen codeword index = 1229
# Block 119: chosen codeword index = 9949
# Block 120: chosen codeword index = 14321
# Block 121: chosen codeword index = 0
# Block 122: chosen codeword index = 19227
# Block 123: chosen codeword index = 0
# Block 124: chosen codeword index = 7732
# Block 125: chosen codeword index = 0
# Block 126: chosen codeword index = 0
# Block 127: chosen codeword index = 213
# Block 128: chosen codeword index = 0
# Block 129: chosen codeword index = 2234
# Block 130: chosen codeword index = 0
# Block 131: chosen codeword index = 12768
# Block 132: chosen codeword index = 19278
# Block 133: chosen codeword index = 0
# Block 134: chosen codeword index = 9663
# Block 135: chosen codeword index = 2229
# Block 136: chosen codeword index = 0
# Block 137: chosen codeword index = 12254
# Block 138: chosen codeword index = 10481
# Block 139: chosen codeword index = 5061
# Block 140: chosen codeword index = 5713
# Block 141: chosen codeword index = 1792
# Block 142: chosen codeword index = 30403
# Block 143: chosen codeword index = 0
# Block 144: chosen codeword index = 4398
# Block 145: chosen codeword index = 957
# Block 146: chosen codeword index = 25623
# Block 147: chosen codeword index = 2719
# Block 148: chosen codeword index = 3582
# Block 149: chosen codeword index = 0
# Block 150: chosen codeword index = 78861
# Block 151: chosen codeword index = 1294
# Block 152: chosen codeword index = 19771
# Block 153: chosen codeword index = 0
# Block 154: chosen codeword index = 11462
# Block 155: chosen codeword index = 0
# Block 156: chosen codeword index = 8442
# Block 157: chosen codeword index = 12150
# Block 158: chosen codeword index = 3755
# Block 159: chosen codeword index = 1891
# Block 160: chosen codeword index = 10868
# Block 161: chosen codeword index = 2431
# Block 162: chosen codeword index = 3423
# Block 163: chosen codeword index = 18932
# Block 164: chosen codeword index = 0
# Block 165: chosen codeword index = 0
# Block 166: chosen codeword index = 14
# Block 167: chosen codeword index = 2520
# Block 168: chosen codeword index = 19397
# Block 169: chosen codeword index = 17972
# Block 170: chosen codeword index = 12710
# Block 171: chosen codeword index = 0
# Block 172: chosen codeword index = 18896
# Block 173: chosen codeword index = 27631
# Block 174: chosen codeword index = 8871
# Block 175: chosen codeword index = 0
# Block 176: chosen codeword index = 0
# Block 177: chosen codeword index = 5259
# Block 178: chosen codeword index = 12446
# Block 179: chosen codeword index = 13600
# Block 180: chosen codeword index = 74
# Block 181: chosen codeword index = 7126
# Block 182: chosen codeword index = 24947
# Block 183: chosen codeword index = 12804
# Block 184: chosen codeword index = 696
# Block 185: chosen codeword index = 0
# Block 186: chosen codeword index = 810
# Block 187: chosen codeword index = 397
# Block 188: chosen codeword index = 4614
# Block 189: chosen codeword index = 0
# Block 190: chosen codeword index = 11099
# Block 191: chosen codeword index = 8016
# Block 192: chosen codeword index = 52346
# Block 193: chosen codeword index = 11744
# Block 194: chosen codeword index = 27791
# Block 195: chosen codeword index = 2224
# Block 196: chosen codeword index = 9635
# Block 197: chosen codeword index = 6029
# Block 198: chosen codeword index = 12955
# Block 199: chosen codeword index = 15044
# Block 200: chosen codeword index = 90513
# Block 201: chosen codeword index = 12774
# Block 202: chosen codeword index = 62265
# Block 203: chosen codeword index = 2591
# Block 204: chosen codeword index = 14478
# Block 205: chosen codeword index = 0
# Block 206: chosen codeword index = 1076
# Block 207: chosen codeword index = 146
# Block 208: chosen codeword index = 17586
# Block 209: chosen codeword index = 20541
# Block 210: chosen codeword index = 9940
# Block 211: chosen codeword index = 8735
# Block 212: chosen codeword index = 0
# Block 213: chosen codeword index = 12722
# Block 214: chosen codeword index = 0
# Block 215: chosen codeword index = 4140
# Block 216: chosen codeword index = 29296
# Block 217: chosen codeword index = 7556
# Block 218: chosen codeword index = 497
# Block 219: chosen codeword index = 0
# Block 220: chosen codeword index = 0
# Block 221: chosen codeword index = 7730
# Block 222: chosen codeword index = 56429
# Block 223: chosen codeword index = 0
# Block 224: chosen codeword index = 11861
# Block 225: chosen codeword index = 5587
# Block 226: chosen codeword index = 0
# Block 227: chosen codeword index = 8010
# Block 228: chosen codeword index = 13712
# Block 229: chosen codeword index = 42997
# Block 230: chosen codeword index = 562
# Block 231: chosen codeword index = 6181
# Block 232: chosen codeword index = 13542
# Block 233: chosen codeword index = 3302
# Block 234: chosen codeword index = 17586
# Block 235: chosen codeword index = 9201
# Block 236: chosen codeword index = 6508
# Block 237: chosen codeword index = 15881
# Block 238: chosen codeword index = 3343
# Block 239: chosen codeword index = 0
# Block 240: chosen codeword index = 0
# Block 241: chosen codeword index = 47648
# Block 242: chosen codeword index = 4913
# Block 243: chosen codeword index = 12976
# Block 244: chosen codeword index = 14239
# Block 245: chosen codeword index = 11367
# Block 246: chosen codeword index = 606
# Block 247: chosen codeword index = 17138
# Block 248: chosen codeword index = 0
# Block 249: chosen codeword index = 0
# Block 250: chosen codeword index = 8140
# Block 251: chosen codeword index = 0
# Block 252: chosen codeword index = 807
# Block 253: chosen codeword index = 0
# Block 254: chosen codeword index = 0
# Block 255: chosen codeword index = 6334
# Block 256: chosen codeword index = 6183
# Block 257: chosen codeword index = 28
# Block 258: chosen codeword index = 438
# Block 259: chosen codeword index = 3909
# Block 260: chosen codeword index = 7684
# Block 261: chosen codeword index = 5797
# Block 262: chosen codeword index = 41741
# Block 263: chosen codeword index = 20677
# Block 264: chosen codeword index = 0
# Block 265: chosen codeword index = 0
# Block 266: chosen codeword index = 8466
# Block 267: chosen codeword index = 0
# Block 268: chosen codeword index = 0
# Block 269: chosen codeword index = 5925
# Block 270: chosen codeword index = 3203
# Block 271: chosen codeword index = 0
# Block 272: chosen codeword index = 0
# Block 273: chosen codeword index = 0
# Block 274: chosen codeword index = 17424
# Block 275: chosen codeword index = 3831
# Block 276: chosen codeword index = 0
# Block 277: chosen codeword index = 3562
# Block 278: chosen codeword index = 8826
# Block 279: chosen codeword index = 10696
# Block 280: chosen codeword index = 7151
# Block 281: chosen codeword index = 4696
# Block 282: chosen codeword index = 0
# Block 283: chosen codeword index = 0
# Block 284: chosen codeword index = 0
# Block 285: chosen codeword index = 8301
# Block 286: chosen codeword index = 65118
# Block 287: chosen codeword index = 0
# Block 288: chosen codeword index = 42498
# Block 289: chosen codeword index = 52
# Block 290: chosen codeword index = 4458
# Block 291: chosen codeword index = 0
# Block 292: chosen codeword index = 326
# Block 293: chosen codeword index = 55011
# Block 294: chosen codeword index = 4280
# Block 295: chosen codeword index = 6723
# Block 296: chosen codeword index = 0
# Block 297: chosen codeword index = 1338
# Block 298: chosen codeword index = 8727
# Block 299: chosen codeword index = 0
# Block 300: chosen codeword index = 20014
# Block 301: chosen codeword index = 18223
# Block 302: chosen codeword index = 2933
# Block 303: chosen codeword index = 6348
# Block 304: chosen codeword index = 0
# Block 305: chosen codeword index = 9227
# Block 306: chosen codeword index = 3372
# Block 307: chosen codeword index = 7768
# Block 308: chosen codeword index = 3209
# Block 309: chosen codeword index = 19609
# Block 310: chosen codeword index = 75567
# Block 311: chosen codeword index = 6020
# Block 312: chosen codeword index = 3879
# Block 313: chosen codeword index = 9352
# Block 314: chosen codeword index = 17552
# Block 315: chosen codeword index = 2242
# Block 316: chosen codeword index = 0
# Block 317: chosen codeword index = 2760
# Block 318: chosen codeword index = 0
# Block 319: chosen codeword index = 15225
# Block 320: chosen codeword index = 4901
# Block 321: chosen codeword index = 0
# Block 322: chosen codeword index = 8137
# Block 323: chosen codeword index = 2931
# Block 324: chosen codeword index = 211
# Block 325: chosen codeword index = 5282
# Block 326: chosen codeword index = 21356
# Block 327: chosen codeword index = 626
# Block 328: chosen codeword index = 0
# Block 329: chosen codeword index = 2596
# Block 330: chosen codeword index = 29624
# Block 331: chosen codeword index = 10891
# Block 332: chosen codeword index = 6730
# Block 333: chosen codeword index = 7816
# Block 334: chosen codeword index = 4180
# Block 335: chosen codeword index = 27377
# Block 336: chosen codeword index = 56886
# Block 337: chosen codeword index = 3281
# Block 338: chosen codeword index = 16096
# Block 339: chosen codeword index = 6545
# Block 340: chosen codeword index = 8047
# Block 341: chosen codeword index = 14623
# Block 342: chosen codeword index = 1235
# Block 343: chosen codeword index = 8363
# Block 344: chosen codeword index = 0
# Block 345: chosen codeword index = 201
# Block 346: chosen codeword index = 0
# Block 347: chosen codeword index = 4242
# Block 348: chosen codeword index = 1756
# Block 349: chosen codeword index = 6236
# Block 350: chosen codeword index = 9221
# Block 351: chosen codeword index = 22233
# Block 352: chosen codeword index = 4308
# Block 353: chosen codeword index = 12903
# Block 354: chosen codeword index = 0
# Block 355: chosen codeword index = 21867
# Block 356: chosen codeword index = 0
# Block 357: chosen codeword index = 4473
# Block 358: chosen codeword index = 13307
# Block 359: chosen codeword index = 304
# Block 360: chosen codeword index = 0
# Block 361: chosen codeword index = 1266
# Block 362: chosen codeword index = 6450
# Block 363: chosen codeword index = 0
# Block 364: chosen codeword index = 0
# Block 365: chosen codeword index = 3936
# Block 366: chosen codeword index = 43749
# Block 367: chosen codeword index = 383
# Block 368: chosen codeword index = 0
# Block 369: chosen codeword index = 11421
# Block 370: chosen codeword index = 0
# Block 371: chosen codeword index = 40364
# Block 372: chosen codeword index = 10571
# Block 373: chosen codeword index = 2217
# Block 374: chosen codeword index = 32691
# Block 375: chosen codeword index = 3284
# Block 376: chosen codeword index = 0
# Block 377: chosen codeword index = 0
# Block 378: chosen codeword index = 5735
# Block 379: chosen codeword index = 30545
# Block 380: chosen codeword index = 0
# Block 381: chosen codeword index = 6094
# Block 382: chosen codeword index = 9262
# Block 383: chosen codeword index = 4727
# Block 384: chosen codeword index = 1921
# Block 385: chosen codeword index = 904
# Block 386: chosen codeword index = 17433

# %%
print("eps=0.11, Error source count =  483"
